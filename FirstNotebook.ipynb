# %% [markdown]
# <a href="https://colab.research.google.com/github/munkeypuff12-maker/ai-data-science/blob/main/FirstNotebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Ask the student to enter their name.
name = input("what is your name?")
# Out:
# what is your name?Jason

# %%
scores = [85, 90, 95]
average = sum(scores)/len(scores)
print("hello,", name)
print("Your average score is: ", average)
# Out:
# hello, Jason
# Your average score is:  90.0
